# %% [markdown]
# # New Datasets Test

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import autometacal as amc
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from scipy.stats import norm

# %% [markdown]
# ## Gal Gen

# %%
batch_size=64
data= tfds.load('GalGen/small_stamp_1k')
data = data['train'].cache()
data = data.repeat()
data = data.shuffle(10)
data = data.batch(batch_size)
data = data.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /local/home/az264973/tensorflow_datasets/gal_gen/small_stamp_1k/2.0.0...
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling gal_gen-train.tfrecord...:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset gal_gen downloaded and prepared to /local/home/az264973/tensorflow_datasets/gal_gen/small_stamp_1k/2.0.0. Subsequent calls will reuse this data.

# %%
batchit = data.as_numpy_iterator()
onebatch = batchit.next()
gal_images,psf_images = onebatch['obs_image'],onebatch['psf_image']

# %%
style.use('default')
figure(figsize=(10,10))
for i in range(16):
  subplot(4,4,i+1)
  imshow(gal_images[i])

# %% [markdown]
# ## CFIS

# %%
batch_size=64
data= tfds.load('CFIS/parametric_1k')
data = data['train'].cache()
data = data.repeat()
data = data.shuffle(10)
data = data.batch(batch_size)
data = data.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /local/home/az264973/tensorflow_datasets/cfis/parametric_1k/0.5.0...
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling cfis-train.tfrecord...:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset cfis downloaded and prepared to /local/home/az264973/tensorflow_datasets/cfis/parametric_1k/0.5.0. Subsequent calls will reuse this data.

# %%
batchit = data.as_numpy_iterator()
onebatch = batchit.next()
gal_images,psf_images = onebatch['obs'],onebatch['psf']

# %%
style.use('default')
figure(figsize=(10,10))
for i in range(16):
  subplot(4,4,i+1)
  imshow(gal_images[i])

# %% [markdown]
# ## Simple

# %%
batch_size=64
data= tfds.load('Simple/small_1k_g1m')
data = data['train'].cache()
data = data.repeat()
data = data.shuffle(10)
data = data.batch(batch_size)
data = data.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /local/home/az264973/tensorflow_datasets/simple/small_1k_g1m/1.0.0...
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling simple-train.tfrecord...:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset simple downloaded and prepared to /local/home/az264973/tensorflow_datasets/simple/small_1k_g1m/1.0.0. Subsequent calls will reuse this data.

# %%
batchit = data.as_numpy_iterator()
onebatch = batchit.next()
gal_images,psf_images = onebatch['obs'],onebatch['psf']

# %%
style.use('default')
figure(figsize=(10,10))
for i in range(16):
  subplot(4,4,i+1)
  imshow(gal_images[i])
